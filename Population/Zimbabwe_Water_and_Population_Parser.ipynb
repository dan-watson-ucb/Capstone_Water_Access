# %%
#!pip install georasters
#!pip install geoindex
#!pip install spark
#!pip install pyspark

# %%
import pandas as pd
import georasters as gr
import matplotlib.pyplot as plt
from geoindex import GeoGridIndex, GeoPoint
import os
from tqdm import tqdm, tqdm_pandas

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Load Water Data

# %%
os.getcwd()
# Out:
# '/Users/alexjamar/Documents/Berkeley/Capstone/Capstone_Water_Access/Population'

# %%
water_data = pd.read_csv("/Users/alexjamar/Documents/Berkeley/Capstone/Capstone_Water_Access//data/Water_Point_Data_Exchange_Complete_Dataset.csv")
# Out:
# /Users/alexjamar/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (2,5,7,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
water_data.head()
# Out:
#    Row ID                 #country_name         #water_source  \
# 0       1  Tanzania, United Republic of                Spring
# 1       2  Tanzania, United Republic of  Rainwater harvesting
# 2       3  Tanzania, United Republic of  Rainwater harvesting
# 3       4  Tanzania, United Republic of  Rainwater harvesting
# 4       5                     Nicaragua                   NaN
#
#                   #water_tech #status_id #management       #pay    #installer  \
# 0  Gravity Communal standpipe         no         NaN  Never pay           RWE
# 1  Gravity Communal standpipe        yes         NaN  Never pay  World Vision
# 2  Gravity Communal standpipe        yes         NaN  Never pay  World Vision
# 3  Gravity Communal standpipe        yes         NaN  Never pay  World Vision
# 4                         NaN        yes         NaN        NaN           NaN
#
#    #install_year                                            #status  \
# 0         1972.0    Status:Not functional|Quantity:Dry|Quality:Soft
# 1         2005.0  Status:Functional|Breakdown Year:2007|Reason N...
# 2         2005.0   Status:Functional|Quantity:Seasonal|Quality:Soft
# 3         2005.0   Status:Functional|Quantity:Seasonal|Quality:Soft
# 4         2011.0                                                NaN
#
#         #source      #adm1      #adm2       #wpdx_id  \
# 0           SNV     Arusha    Longido  wpdx-00000001
# 1           SNV     Arusha    Longido  wpdx-00000002
# 2           SNV     Arusha    Longido  wpdx-00000003
# 3           SNV     Arusha    Longido  wpdx-00000004
# 4  El Porvenier  Matagalpa  Terrabona  wpdx-00000005
#
#                    #report_date #country_id #activity_id  \
# 0  01/05/2008 12:00:00 AM +0000          TZ          NaN
# 1  01/01/2008 12:00:00 AM +0000          TZ          NaN
# 2  01/01/2008 12:00:00 AM +0000          TZ          NaN
# 3  01/01/2008 12:00:00 AM +0000          TZ          NaN
# 4  01/01/2011 12:00:00 AM +0000          NI          NaN
#
#                                            #data_lnk  \
# 0  http://www.dropbox.com/s/50779gal9v4z4y6/TZ%20...
# 1  http://www.dropbox.com/s/50779gal9v4z4y6/TZ%20...
# 2  http://www.dropbox.com/s/50779gal9v4z4y6/TZ%20...
# 3  http://www.dropbox.com/s/50779gal9v4z4y6/TZ%20...
# 4  http://www.dropbox.com/s/0f70mln5roxhy29/ProjT...
#
#                                            #orig_lnk photo_lnk  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3                                                NaN       NaN
# 4  https://www.waterpointdata.org/dataset/resourc...       NaN
#
#                                    #converted                      #created  \
# 0       "#water_tech, #country_id, #data_lnk"  10/23/2015 01:03:07 AM +0000
# 1       "#water_tech, #country_id, #data_lnk"  10/23/2015 01:03:07 AM +0000
# 2       "#water_tech, #country_id, #data_lnk"  10/23/2015 01:03:07 AM +0000
# 3       "#water_tech, #country_id, #data_lnk"  10/23/2015 01:03:07 AM +0000
# 4  #data_lnk, #lon_deg, #lat_deg, #country_id  04/08/2016 08:35:49 AM +0000
#
#                        #updated  #lat_deg  #lon_deg             Location  \
# 0  10/23/2015 01:03:07 AM +0000  -2.83257   36.3090   (-2.83257, 36.309)
# 1  10/23/2015 01:03:07 AM +0000  -2.84781   36.5284  (-2.84781, 36.5284)
# 2  10/23/2015 01:03:07 AM +0000  -2.84796   36.5288  (-2.84796, 36.5288)
# 3  10/23/2015 01:03:07 AM +0000  -2.85318   36.5276  (-2.85318, 36.5276)
# 4  04/08/2016 08:35:49 AM +0000  12.74070  -86.0121  (12.7407, -86.0121)
#
#    Count  #fecal_coliform_presence  #fecal_coliform_value  #subjective_quality
# 0      1                       NaN                    NaN                  NaN
# 1      1                       NaN                    NaN                  NaN
# 2      1                       NaN                    NaN                  NaN
# 3      1                       NaN                    NaN                  NaN
# 4      1                       NaN                    NaN                  NaN

# %%
zimbabwe_water = water_data[water_data['#country_name'] == 'Zimbabwe']

# %%
zimbabwe_water.head()
# Out:
#         Row ID #country_name #water_source    #water_tech #status_id  \
# 296889  467162      Zimbabwe      Borehole      Bush Pump        yes
# 296923  467163      Zimbabwe      Borehole      Bush Pump        yes
# 296956  467164      Zimbabwe      Borehole  India Mark II        yes
# 297007  467165      Zimbabwe      Borehole  India Mark II        yes
# 297024  467166      Zimbabwe      Borehole      Bush Pump        yes
#
#        #management #pay #installer  #install_year #status  \
# 296889         NaN  NaN        NaN         2014.0     NaN
# 296923         NaN  NaN        NaN         2014.0     NaN
# 296956         NaN  NaN        NaN         2014.0     NaN
# 297007         NaN  NaN        NaN         2014.0     NaN
# 297024         NaN  NaN        NaN         2013.0     NaN
#
#                            #source #adm1 #adm2       #wpdx_id  \
# 296889  Living Water International   NaN   NaN  wpdx-00467162
# 296923  Living Water International   NaN   NaN  wpdx-00467163
# 296956  Living Water International   NaN   NaN  wpdx-00467164
# 297007  Living Water International   NaN   NaN  wpdx-00467165
# 297024  Living Water International   NaN   NaN  wpdx-00467166
#
#                         #report_date #country_id          #activity_id  \
# 296889  03/27/2014 12:00:00 AM +0000          ZW  ZW131216LWI001005ZMB
# 296923  03/27/2014 12:00:00 AM +0000          ZW  ZW131216LWI005005ZMB
# 296956  05/06/2014 12:00:00 AM +0000          ZW  SRZW1406020004523ZMB
# 297007  05/05/2014 12:00:00 AM +0000          ZW  SRZW1406020004514ZMB
# 297024  03/08/2014 12:00:00 AM +0000          ZW  ZW130723LWI009010ZMB
#
#        #data_lnk                                          #orig_lnk photo_lnk  \
# 296889       NaN  https://www.waterpointdata.org/dataset/resourc...       NaN
# 296923       NaN  https://www.waterpointdata.org/dataset/resourc...       NaN
# 296956       NaN  https://www.waterpointdata.org/dataset/resourc...       NaN
# 297007       NaN  https://www.waterpointdata.org/dataset/resourc...       NaN
# 297024       NaN  https://www.waterpointdata.org/dataset/resourc...       NaN
#
#        #converted                      #created                      #updated  \
# 296889        NaN  12/12/2016 05:27:40 PM +0000  12/12/2016 05:27:40 PM +0000
# 296923        NaN  12/12/2016 05:27:40 PM +0000  12/12/2016 05:27:40 PM +0000
# 296956        NaN  12/12/2016 05:27:40 PM +0000  12/12/2016 05:27:40 PM +0000
# 297007        NaN  12/12/2016 05:27:40 PM +0000  12/12/2016 05:27:40 PM +0000
# 297024        NaN  12/12/2016 05:27:40 PM +0000  12/12/2016 05:27:40 PM +0000
#
#         #lat_deg  #lon_deg             Location  Count  \
# 296889  -20.0438   27.7201  (-20.0438, 27.7201)      1
# 296923  -20.0351   27.7579  (-20.0351, 27.7579)      1
# 296956  -20.0209   27.2812  (-20.0209, 27.2812)      1
# 297007  -20.0140   27.4260    (-20.014, 27.426)      1
# 297024  -20.0024   27.7914  (-20.0024, 27.7914)      1
#
#         #fecal_coliform_presence  #fecal_coliform_value  #subjective_quality
# 296889                       NaN                    NaN                  NaN
# 296923                       NaN                    NaN                  NaN
# 296956                       NaN                    NaN                  NaN
# 297007                       NaN                    NaN                  NaN
# 297024                       NaN                    NaN                  NaN

# %% [markdown]
# ## Radius-based Search

# %%
zimbabwe_pop = pd.read_csv("Zimbabwe_pop_data.csv")

# %%
#Create Geo Index of Zimbabwe Population Data
geo_index = GeoGridIndex()
for index, row in zimbabwe_pop.iterrows():
    geo_index.add_point(GeoPoint(row['y'], row['x'], ref=row['value']))

# %%
#Create Geo Index of Zimbabwe Water Point Data
geo_index_water = GeoGridIndex()
for index, row in zimbabwe_water.iterrows():
    try:
        geo_index_water.add_point(GeoPoint(row['#lat_deg'], row['#lon_deg'], ref=row['#status_id']))
    except:
        print("Row ID:", row['Row ID'])
        print("Lat:", row['#lat_deg'])
        print("Long:", row['#lon_deg'])

# %%
#Calculate population within x distance of water point
def calculate_population_within_x_km(row, index, km):
    center_point = GeoPoint(row['#lat_deg'], row['#lon_deg'])
    total_population = 0
    try:
        for point,distance in index.get_nearest_points(center_point, km, 'km'):
            total_population += point.ref
    except:
        print("Invalid data - Record skipped")
    #print("Total population within", km, "kilometers:", int(total_population))
    return total_population

# %%
#Calculate # of water points within x distance of water point
def calculate_water_points_within_x_km(row, index, km):
    center_point = GeoPoint(row['#lat_deg'], row['#lon_deg'])
    total_water_points = 0
    total_functioning_water_points = 0
    try:
        for point,distance in index.get_nearest_points(center_point, km, 'km'):
            total_water_points += 1
            if point.ref == 'yes':
                total_functioning_water_points += 1
    except:
        print("Invalid data - Record skipped")
        
    #Adjust for self
    total_water_points -= 1
    if row['#status_id'] == 'yes':
        total_functioning_water_points -= 1
    return (total_water_points, total_functioning_water_points)

# %%
#Add 1 km radius population data to each well
tqdm.pandas()
zimbabwe_water['1 km population'] = zimbabwe_water.progress_apply(lambda row: calculate_population_within_x_km(row, geo_index, 1),
                                                  axis = 1)
# Out:
# 100%|██████████| 38777/38777 [73:17:13<00:00,  6.80s/it]
# /Users/alexjamar/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#Add 1 km radius water point data to each water point
tqdm.pandas()
zimbabwe_water['1 km water points (total, functioning)'] = zimbabwe_water.progress_apply(lambda row: calculate_water_points_within_x_km(row, geo_index_water, 1),
                                                  axis = 1)
# Out:
# 100%|██████████| 38777/38777 [03:57<00:00, 163.10it/s]
# /Users/alexjamar/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
zimbabwe_water.head(2)
# Out:
#         Row ID #country_name #water_source #water_tech #status_id #management  \
# 296889  467162      Zimbabwe      Borehole   Bush Pump        yes         NaN
# 296923  467163      Zimbabwe      Borehole   Bush Pump        yes         NaN
#
#        #pay #installer  #install_year #status                     #source  \
# 296889  NaN        NaN         2014.0     NaN  Living Water International
# 296923  NaN        NaN         2014.0     NaN  Living Water International
#
#        #adm1 #adm2       #wpdx_id                  #report_date #country_id  \
# 296889   NaN   NaN  wpdx-00467162  03/27/2014 12:00:00 AM +0000          ZW
# 296923   NaN   NaN  wpdx-00467163  03/27/2014 12:00:00 AM +0000          ZW
#
#                 #activity_id #data_lnk  \
# 296889  ZW131216LWI001005ZMB       NaN
# 296923  ZW131216LWI005005ZMB       NaN
#
#                                                 #orig_lnk photo_lnk  \
# 296889  https://www.waterpointdata.org/dataset/resourc...       NaN
# 296923  https://www.waterpointdata.org/dataset/resourc...       NaN
#
#        #converted                      #created                      #updated  \
# 296889        NaN  12/12/2016 05:27:40 PM +0000  12/12/2016 05:27:40 PM +0000
# 296923        NaN  12/12/2016 05:27:40 PM +0000  12/12/2016 05:27:40 PM +0000
#
#         #lat_deg  #lon_deg             Location  Count  \
# 296889  -20.0438   27.7201  (-20.0438, 27.7201)      1
# 296923  -20.0351   27.7579  (-20.0351, 27.7579)      1
#
#         #fecal_coliform_presence  #fecal_coliform_value  #subjective_quality  \
# 296889                       NaN                    NaN                  NaN
# 296923                       NaN                    NaN                  NaN
#
#         1 km population 1 km water points (total, functioning)
# 296889          145.291                                 (4, 3)
# 296923          303.316                                 (2, 2)

# %%
def clean_water_data(df):
    df['1 km population'] = df['1 km population'].apply(lambda x: int(round(x,0)))
    df['1 km total water points'] = df['1 km water points (total, functioning)'].apply(lambda x: str(x).split(',')[0][1:])
    df['1 km functioning water points'] = df['1 km water points (total, functioning)'].apply(lambda x: str(x).split(',')[1][:-1])
    df = df[['Row ID', '#country_name', '#status_id', '#lat_deg', '#lon_deg', '1 km population',
                        '1 km total water points', '1 km functioning water points']]
    
    return df

# %%
zimbabwe_abridged = clean_water_data(zimbabwe_water)
# Out:
# /Users/alexjamar/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/alexjamar/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alexjamar/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
zimbabwe_abridged.head()
# Out:
#         Row ID #country_name #status_id  #lat_deg  #lon_deg  1 km population  \
# 296889  467162      Zimbabwe        yes  -20.0438   27.7201              145
# 296923  467163      Zimbabwe        yes  -20.0351   27.7579              303
# 296956  467164      Zimbabwe        yes  -20.0209   27.2812              689
# 297007  467165      Zimbabwe        yes  -20.0140   27.4260              110
# 297024  467166      Zimbabwe        yes  -20.0024   27.7914              206
#
#        1 km total water points 1 km functioning water points
# 296889                       4                             3
# 296923                       2                             2
# 296956                       1                             1
# 297007                       0                             0
# 297024                       3                             3

# %%
zimbabwe_abridged.to_csv("Abridged_Zimbabwe_Water_and_Population_Data.csv", index = False)
